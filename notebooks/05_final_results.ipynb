# %% [markdown]
# # 05 Final Results
# Load saved summaries, tables, and report assets after the full pipeline finishes.

# %%
import pandas as pd
pd.read_csv('results/tables/final_evaluation_table.csv')
