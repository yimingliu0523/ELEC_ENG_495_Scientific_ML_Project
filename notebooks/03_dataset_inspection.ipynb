# %% [markdown]
# # 03 Dataset Inspection
# Inspect processed train/validation/test trajectory arrays and normalization statistics.

# %%
from src.data.dataset import load_dataset_arrays
arrays = load_dataset_arrays('results/data/processed/lorenz_dataset.npz')
{key: value.shape if hasattr(value, 'shape') else value for key, value in arrays.items()}
