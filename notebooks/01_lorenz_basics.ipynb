# %% [markdown]
# # 01 Lorenz Basics
# Use this notebook to inspect the standard Lorenz trajectory and basic attractor geometry.

# %%
from src.dynamics.dataset_generation import build_time_grid
from src.dynamics.simulation import generate_single_trajectory
from src.dynamics.lorenz import get_default_lorenz_params
import numpy as np
time_grid = build_time_grid(25.0, 0.01)
trajectory = generate_single_trajectory(np.array([1.0, 1.0, 1.0]), time_grid, get_default_lorenz_params())
trajectory[:5]
