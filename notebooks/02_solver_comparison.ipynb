# %% [markdown]
# # 02 Solver Comparison
# Compare RK4 and alternative solver settings on the Lorenz system.

# %%
from src.dynamics.dataset_generation import build_time_grid
from src.dynamics.solvers import simulate_trajectory
from src.dynamics.lorenz import get_default_lorenz_params
import numpy as np
params = get_default_lorenz_params()
fine_grid = build_time_grid(25.0, 0.005)
trajectory = simulate_trajectory(np.array([1.0, 1.0, 1.0]), fine_grid, params=params, solver='rk4')
trajectory.shape
