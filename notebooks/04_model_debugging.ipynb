# %% [markdown]
# # 04 Model Debugging
# Use this notebook to inspect batch shapes and forward passes for each model family.

# %%
import torch
from src.models import build_model
mlp = build_model('mlp', {'state_dim': 3, 'history_steps': 1, 'hidden_dims': [64, 64], 'activation': 'relu'})
x = torch.randn(8, 3)
mlp(x).shape
